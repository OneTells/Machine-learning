# %% [raw]
# https://www.kaggle.com/code/aikenkazin/ddos-attack-detection-classification/notebook
# https://www.kaggle.com/datasets/aikenkazin/ddos-sdn-dataset/code

# %% [raw]
# Не сделано!!!

# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv(r'..\Data\dataset_sdn.csv')

# %%
data.head()
# Out:
#       dt  switch       src       dst  pktcount  bytecount  dur   dur_nsec  \
# 0  11425       1  10.0.0.1  10.0.0.8     45304   48294064  100  716000000
# 1  11605       1  10.0.0.1  10.0.0.8    126395  134737070  280  734000000
# 2  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
# 3  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
# 4  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
#
#         tot_dur  flows  ...  pktrate  Pairflow  Protocol  port_no   tx_bytes  \
# 0  1.010000e+11      3  ...      451         0       UDP        3  143928631
# 1  2.810000e+11      2  ...      451         0       UDP        4       3842
# 2  2.010000e+11      3  ...      451         0       UDP        1       3795
# 3  2.010000e+11      3  ...      451         0       UDP        2       3688
# 4  2.010000e+11      3  ...      451         0       UDP        3       3413
#
#   rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0     3917        0      0.0       0.0      0
# 1     3520        0      0.0       0.0      0
# 2     1242        0      0.0       0.0      0
# 3     1492        0      0.0       0.0      0
# 4     3665        0      0.0       0.0      0
#
# [5 rows x 23 columns]

# %% [raw]
# dt
# switch
# src
# dst
# pktcount
# bytecount
# dur
# dur_nsec
# tot_dur
# flows
# packetins
# pktperflow
# byteperflow
# pktrate
# Pairflow
# Protocol
# port_no
# tx_bytes
# rx_bytes
# tx_kbps
# rx_kbps
# tot_kbps
# label: 1 вредоносный, 0 доброкачественный трафик

# %%
data.shape
# Out:
# (104345, 23)

# %%
data = data[['dt','switch','src','label']]

# %%
data.head()

# %%
data.describe().T
# Out:
#                 count          mean           std          min           25%  \
# dt           104345.0  1.792751e+04  1.197764e+04       2488.0  7.098000e+03
# switch       104345.0  4.214260e+00  1.956327e+00          1.0  3.000000e+00
# pktcount     104345.0  5.286095e+04  5.202324e+04          0.0  8.080000e+02
# bytecount    104345.0  3.818660e+07  4.877748e+07          0.0  7.957600e+04
# dur          104345.0  3.214974e+02  2.835182e+02          0.0  1.270000e+02
# dur_nsec     104345.0  4.613880e+08  2.770019e+08          0.0  2.340000e+08
# tot_dur      104345.0  3.218865e+11  2.834029e+11          0.0  1.270000e+11
# flows        104345.0  5.654234e+00  2.950036e+00          2.0  3.000000e+00
# packetins    104345.0  5.200383e+03  5.257001e+03          4.0  1.943000e+03
# pktperflow   104345.0  6.381715e+03  7.404778e+03    -130933.0  2.900000e+01
# byteperflow  104345.0  4.716150e+06  7.560116e+06 -146442594.0  2.842000e+03
# pktrate      104345.0  2.122107e+02  2.468551e+02      -4365.0  0.000000e+00
# Pairflow     104345.0  6.009871e-01  4.896978e-01          0.0  0.000000e+00
# port_no      104345.0  2.331094e+00  1.084333e+00          1.0  1.000000e+00
# tx_bytes     104345.0  9.325264e+07  1.519380e+08       2527.0  4.743000e+03
# rx_bytes     104345.0  9.328039e+07  1.330004e+08        856.0  3.539000e+03
# tx_kbps      104345.0  9.988998e+02  2.423472e+03          0.0  0.000000e+00
# rx_kbps      103839.0  1.003811e+03  2.054887e+03          0.0  0.000000e+00
# tot_kbps     103839.0  2.007579e+03  3.144437e+03          0.0  0.000000e+00
# label        104345.0  3.908573e-01  4.879448e-01          0.0  0.000000e+00
#
#                       50%           75%           max
# dt           1.190500e+04  2.995200e+04  4.293500e+04
# switch       4.000000e+00  5.000000e+00  1.000000e+01
# pktcount     4.282800e+04  9.479600e+04  2.600060e+05
# bytecount    6.471930e+06  7.620354e+07  1.471280e+08
# dur          2.510000e+02  4.120000e+02  1.881000e+03
# dur_nsec     4.180000e+08  7.030000e+08  9.990000e+08
# tot_dur      2.520000e+11  4.130000e+11  1.880000e+12
# flows        5.000000e+00  7.000000e+00  1.700000e+01
# packetins    3.024000e+03  7.462000e+03  2.522400e+04
# pktperflow   8.305000e+03  1.001700e+04  1.919000e+04
# byteperflow  5.521680e+05  9.728112e+06  1.495387e+07
# pktrate      2.760000e+02  3.330000e+02  6.390000e+02
# Pairflow     1.000000e+00  1.000000e+00  1.000000e+00
# port_no      2.000000e+00  3.000000e+00  5.000000e+00
# tx_bytes     4.219610e+06  1.356398e+08  1.269982e+09
# rx_bytes     1.338339e+07  1.439277e+08  9.905962e+08
# tx_kbps      0.000000e+00  2.510000e+02  2.058000e+04
# rx_kbps      0.000000e+00  5.570000e+02  1.657700e+04
# tot_kbps     4.000000e+00  3.838000e+03  2.058000e+04
# label        0.000000e+00  1.000000e+00  1.000000e+00

# %%
data['pktcount'].hist()
# Out:
# <Axes: >

# %%
sns.boxplot(data['tx_bytes'])
# Out:
# <Axes: ylabel='tx_bytes'>

# %%
sns.histplot(x='label', data=data)
# Out:
# <Axes: xlabel='label', ylabel='Count'>
